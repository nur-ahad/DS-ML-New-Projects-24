# %%
pip install -U kaleido
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Import Libraries 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the dataset 
dataset = pd.read_csv("Downloads/heart_failure_clinical_records_dataset.csv")

# %%
#EDA 
#Explore the excel file 
dataset
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
#Show the head of the dataset 
dataset.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
#Columans of the dataset 
dataset.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
#Shape of the dataset 
dataset.shape
# Out:
# (299, 13)

# %%
#Information of the dataset 
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
#Check for missing values
dataset.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
#Descriptive Statistics of the dataset 
dataset.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
#Code to findout categorical variables from int64 datatype 
categorical_cols = list(dataset.select_dtypes(include=['int64']).nunique()[lambda x: x <= 10].index)
print(categorical_cols)
# Out:
# ['anaemia', 'diabetes', 'high_blood_pressure', 'sex', 'smoking', 'DEATH_EVENT']

# %%
#Alternative code to findout categorical variables from int64 datatype 
categorical_cols = [col for col in dataset.select_dtypes(include=['int64']) if len(dataset[col].unique()) <= 10]
print(categorical_cols)
# Out:
# ['anaemia', 'diabetes', 'high_blood_pressure', 'sex', 'smoking', 'DEATH_EVENT']

# %%
#Checking Each Features 
dataset.value_counts('age')
# Out:
# age
# 60.000    33
# 50.000    27
# 65.000    26
# 70.000    25
# 45.000    19
# 55.000    17
# 75.000    11
# 58.000    10
# 53.000    10
# 63.000     8
# 40.000     7
# 42.000     7
# 80.000     7
# 72.000     7
# 85.000     6
# 68.000     5
# 62.000     5
# 52.000     5
# 73.000     4
# 59.000     4
# 61.000     4
# 51.000     4
# 49.000     4
# 90.000     3
# 82.000     3
# 64.000     3
# 69.000     3
# 46.000     3
# 57.000     2
# 44.000     2
# 78.000     2
# 77.000     2
# 95.000     2
# 48.000     2
# 67.000     2
# 66.000     2
# 60.667     2
# 54.000     2
# 56.000     1
# 79.000     1
# 41.000     1
# 81.000     1
# 43.000     1
# 86.000     1
# 87.000     1
# 94.000     1
# 47.000     1
# dtype: int64

# %%
dataset.value_counts('anaemia')  #Categorical
# Out:
# anaemia
# 0    170
# 1    129
# dtype: int64

# %%
dataset.value_counts('creatinine_phosphokinase')
# Out:
# creatinine_phosphokinase
# 582     47
# 66       4
# 129      4
# 115      3
# 59       3
#         ..
# 198      1
# 200      1
# 203      1
# 207      1
# 7861     1
# Length: 208, dtype: int64

# %%
dataset.value_counts('diabetes') #Categorical
# Out:
# diabetes
# 0    174
# 1    125
# dtype: int64

# %%
dataset.value_counts('ejection_fraction')
# Out:
# ejection_fraction
# 35    49
# 38    40
# 40    37
# 25    36
# 30    34
# 60    31
# 50    21
# 45    20
# 20    18
# 55     3
# 17     2
# 15     2
# 62     2
# 70     1
# 14     1
# 65     1
# 80     1
# dtype: int64

# %%
dataset.value_counts('high_blood_pressure') #Categorical
# Out:
# high_blood_pressure
# 0    194
# 1    105
# dtype: int64

# %%
dataset.value_counts('platelets')
# Out:
# platelets
# 263358.03    25
# 279000.00     4
# 228000.00     4
# 305000.00     4
# 255000.00     4
#              ..
# 224000.00     1
# 217000.00     1
# 213000.00     1
# 212000.00     1
# 850000.00     1
# Length: 176, dtype: int64

# %%
dataset.value_counts('serum_creatinine')
# Out:
# serum_creatinine
# 1.00    50
# 0.90    32
# 1.10    32
# 0.80    24
# 1.20    24
# 1.30    20
# 0.70    19
# 1.18    11
# 1.40     9
# 1.70     9
# 1.83     8
# 1.60     6
# 1.50     5
# 2.10     5
# 1.90     5
# 0.60     4
# 1.80     4
# 2.30     3
# 2.50     3
# 2.70     3
# 3.00     2
# 3.50     2
# 2.40     2
# 5.00     1
# 5.80     1
# 0.50     1
# 6.10     1
# 6.80     1
# 4.00     1
# 9.00     1
# 4.40     1
# 2.20     1
# 3.80     1
# 3.70     1
# 3.40     1
# 3.20     1
# 2.90     1
# 2.00     1
# 0.75     1
# 9.40     1
# dtype: int64

# %%
dataset.value_counts('serum_sodium')
# Out:
# serum_sodium
# 136    40
# 137    38
# 140    35
# 134    32
# 138    23
# 139    22
# 135    16
# 132    14
# 141    12
# 142    11
# 133    10
# 130     9
# 145     9
# 144     5
# 131     5
# 143     3
# 127     3
# 128     2
# 129     2
# 146     1
# 113     1
# 116     1
# 126     1
# 125     1
# 124     1
# 121     1
# 148     1
# dtype: int64

# %%
dataset.value_counts('sex')     #Categorical
# Out:
# sex
# 1    194
# 0    105
# dtype: int64

# %%
dataset.value_counts('smoking')    #Categorical
# Out:
# smoking
# 0    203
# 1     96
# dtype: int64

# %%
dataset.value_counts('time')
# Out:
# time
# 250    7
# 187    7
# 10     6
# 186    6
# 107    6
#       ..
# 97     1
# 96     1
# 86     1
# 77     1
# 285    1
# Length: 148, dtype: int64

# %%
#Univariate Analysis of Categorical Variables
category_list =['anaemia','high_blood_pressure','diabetes','sex','smoking']

# %%
#Countplot of Anaemia 
sns.countplot(x ='anaemia', data =dataset)
plt.show()

# %%
#Countplot of High Blood Pressure
sns.countplot(x ='high_blood_pressure', data =dataset)
plt.show()

# %%
#Countplot of Diabetes
sns.countplot(x ='diabetes', data =dataset)
plt.show()

# %%
#Countplot of Sex
sns.countplot(x ='sex', data =dataset)
plt.show()

# %%
#Countplot of Smoking 
sns.countplot(x ='smoking', data =dataset)
plt.show()

# %%
#Masterplot /Graphs with Categorical Variable
sns.plotUnivariateAnalysis(data_frame=dataset,
                            category_list=category_list,
                            row=2,cols=3,
                            figsize=(18,20))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_73896\671340197.py in <module>
#       1 #Masterplot /Graphs with Categorical Variable
# ----> 2 sns.plotUnivariateAnalysis(data_frame=dataset,
#       3                             category_list=category_list,
#       4                             row=2,cols=3,
#       5                             figsize=(18,20))
#
# AttributeError: module 'seaborn' has no attribute 'plotUnivariateAnalysis'

# %%
#Strip Plot of Anaemia
sns.stripplot(x ='anaemia', data =dataset)
plt.show()

# %%
#Univariate Analysis of Quantitative Variables
quant_list =['age','creatinine_phosphokinase','ejection_fraction','platelets','serum_creatinine','serum_sodium','time']

# %%
#Histogram of Age 
sns.histplot(data=dataset, x ="age")
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
#Histogram of Creatinine Phosphokinase
sns.histplot(data=dataset, x ="creatinine_phosphokinase")
# Out:
# <AxesSubplot:xlabel='creatinine_phosphokinase', ylabel='Count'>

# %%
#Histogram of Ejection Fraction 
sns.histplot(data=dataset, x ="ejection_fraction")
# Out:
# <AxesSubplot:xlabel='ejection_fraction', ylabel='Count'>

# %%
##Histogram of Platelets
sns.histplot(data=dataset, x ="platelets")
# Out:
# <AxesSubplot:xlabel='platelets', ylabel='Count'>

# %%
##Histogram of Serum Creatinine 
sns.histplot(data=dataset, x ="serum_creatinine")
# Out:
# <AxesSubplot:xlabel='serum_creatinine', ylabel='Count'>

# %%
##Histogram of Serum Sodium 
sns.histplot(data=dataset, x ="serum_sodium")
# Out:
# <AxesSubplot:xlabel='serum_sodium', ylabel='Count'>

# %%
##Histogram of Time
sns.histplot(data=dataset, x ="time")
# Out:
# <AxesSubplot:xlabel='time', ylabel='Count'>

# %%
#Disturbtion of Age with Anaemia (Style 1)
dataset.boxplot(column="age", by="anaemia", figsize=(6,8))
plt.show()

# %%
#Disturbtion of Age with Anaemia (Style 2)
sns.boxplot(x='age', y='anaemia', data=dataset)
# Out:
# <AxesSubplot:xlabel='age', ylabel='anaemia'>

# %%
#Sty# Plot a box plot to show the relationship between numerical and categorical variable
dataset.boxplot(column='age', by='anaemia')
# Set x and y-axis labels
plt.xlabel('anaemia')
plt.ylabel('age')
# Set the title of the plot
plt.title('Relationship between Age and Anaemia')

# Show the plot
plt.show()

# %%
#Style 5 
# Create a box plot with age on the y-axis and anaemia on the x-axis
plt.boxplot([dataset[dataset['anaemia']==0]['age'], dataset[dataset['anaemia']==1]['age']], labels=['No Anaemia', 'Anaemia'])

# Set the axis labels
plt.xlabel('Anaemia')
plt.ylabel('Age')

# Show the plot
plt.show()

# %%
#Style 6 
# Create a violin plot with age on the y-axis and anaemia on the x-axis
sns.violinplot(x="anaemia", y="age", data=dataset)

# Set the axis labels
plt.xlabel('Anaemia')
plt.ylabel('Age')

# Show the plot
plt.show()

# %%
#Style 7 
# Create a swarm plot with age on the y-axis and anaemia on the x-axis
sns.swarmplot(x="anaemia", y="age", hue="anaemia", data=dataset)

# Set the axis labels
plt.xlabel('Anaemia')
plt.ylabel('Age')

# Show the plot
plt.show()

# %%
# Create a swarm plot with age on the y-axis and anaemia on the x-axis
sns.swarmplot(x="anaemia", y="age", hue="anaemia", data=dataset)

# Set the axis labels
plt.xlabel('Anaemia')
plt.ylabel('Age')

# Add horizontal lines for the mean age of each group
mean_anaemia = dataset[dataset['anaemia'] == 1]['age'].mean()
mean_no_anaemia = dataset[dataset['anaemia'] == 0]['age'].mean()
plt.axhline(mean_anaemia, color='r', linestyle='--', label='Mean Age with Anaemia')
plt.axhline(mean_no_anaemia, color='g', linestyle='--', label='Mean Age without Anaemia')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
#Age with all categorical variables 
# Set the plot style
sns.set(style='ticks')

# Create the subplots
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 10))

# Plot the distribution of age vs. anaemia
sns.histplot(data=dataset, x='age', hue='anaemia', kde=True, ax=axs[0, 0])

# Plot the distribution of age vs. diabetes
sns.histplot(data=dataset, x='age', hue='diabetes', kde=True, ax=axs[0, 1])

# Plot the distribution of age vs. high_blood_pressure
sns.histplot(data=dataset, x='age', hue='high_blood_pressure', kde=True, ax=axs[1, 0])

# Plot the distribution of age vs. sex
sns.histplot(data=dataset, x='age', hue='sex', kde=True, ax=axs[1, 1])

# Plot the distribution of age vs. smoking
sns.histplot(data=dataset, x='age', hue='smoking', kde=True)

# Show the plot
plt.show()
