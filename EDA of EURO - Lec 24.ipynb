# %%
# Importing packages 

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the dataset 

df = pd.read_csv("C://Users//nural//Downloads//euro-daily-hist_1999_2022.csv")

# %%
# Displaying first few rows of the dataset 
df.head()
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2024-04-11               1.6448           1.9558            5.4468
# 1   2024-04-10               1.6399           1.9558             5.433
# 2   2024-04-09               1.6407           1.9558            5.4489
# 3   2024-04-08               1.6433           1.9558            5.4806
# 4   2024-04-05               1.6461           1.9558            5.4633
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.4688         0.9787                   7.7646              NaN
# 1             1.4728          0.981                   7.8548              NaN
# 2             1.4749         0.9819                   7.8603              NaN
# 3             1.4715         0.9807                   7.8282              NaN
# 4             1.4702         0.9793                   7.8421              NaN
#
# ...

# %%
# Checking the data types 

df.dtypes
# Out:
# Period\Unit:                 object
# [Australian dollar ]         object
# [Bulgarian lev ]             object
# [Brazilian real ]            object
# [Canadian dollar ]           object
# [Swiss franc ]               object
# [Chinese yuan renminbi ]     object
# [Cypriot pound ]             object
# [Czech koruna ]              object
# [Danish krone ]              object
# [Estonian kroon ]            object
# [UK pound sterling ]         object
# [Greek drachma ]             object
# [Hong Kong dollar ]          object
# [Croatian kuna ]             object
# [Hungarian forint ]          object
# [Indonesian rupiah ]         object
# [Israeli shekel ]            object
# [Indian rupee ]              object
# [Iceland krona ]            float64
# [Japanese yen ]              object
# [Korean won ]                object
# [Lithuanian litas ]          object
# [Latvian lats ]              object
# [Maltese lira ]              object
# [Mexican peso ]              object
# ...

# %%
# Generating summary of the Quantitative Features of the Dataset
df.describe()
# Out:
#        [Iceland krona ]  [Romanian leu ]  [Turkish lira ]
# count       4128.000000      6473.000000      6473.000000
# mean         110.188028         4.006029         4.830528
# std           34.561774         0.881086         6.483560
# min           68.070000         1.291200         0.370100
# 25%           84.090000         3.572500         1.738300
# 50%           90.350000         4.302500         2.285800
# 75%          140.400000         4.632300         4.554800
# max          305.000000         4.978300        35.182500

# %%
# Generating summary of the Object Features of the Dataset

object_columns = df.select_dtypes(include=['object']).columns

# %%
# Displayng summary statistics for object columns 

object_summary= df[object_columns].describe()

# %%
print(object_summary)
# Out:
#        Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# count          6535                 6535             6133              6267
# unique         6535                 3682              106              5656
# top      2018-08-27                    -           1.9558                 -
# freq              1                   62             4800                61
#
#        [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# count                6535           6535                     6267
# unique               3099           3388                     5456
# top                     -              -                        -
# freq                   62             62                       61
#
#        [Cypriot pound ] [Czech koruna ] [Danish krone ]  ...  \
# count              2346            6535            6535  ...
# unique              498            4109             496  ...
# top             0.58420          27.021               -  ...
# ...

# %%
# Plotting bar blots for Object Features (Using Matplotlib)

object_columns = df.select_dtypes(include=['object']).columns

for column in object_columns:
    plt.figure(figsize=(8,6))
    df[column].value_counts().plot(kind='bar')
    plt.title(f'Bar Plot of Currency')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.show()

# %%
# Plotting bar blots for Object Features (Using Seaborn)

object_columns = df.select_dtypes(include=['object']).columns

for column in object_columns:
    plt.figure(figsize=(8,6))
    sns.countplot(x=column, data=df, palette='viridis')
    plt.title(f'Count Plot of Currency')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()

# %%
# Checking for Missing Values

df.isnull().sum()
# Out:
# Period\Unit:                   0
# [Australian dollar ]           0
# [Bulgarian lev ]             402
# [Brazilian real ]            268
# [Canadian dollar ]             0
# [Swiss franc ]                 0
# [Chinese yuan renminbi ]     268
# [Cypriot pound ]            4189
# [Czech koruna ]                0
# [Danish krone ]                0
# [Estonian kroon ]           3405
# [UK pound sterling ]           0
# [Greek drachma ]            6015
# [Hong Kong dollar ]            0
# [Croatian kuna ]             594
# [Hungarian forint ]            0
# [Indonesian rupiah ]           0
# [Israeli shekel ]            268
# [Indian rupee ]              268
# [Iceland krona ]            2407
# [Japanese yen ]                0
# [Korean won ]                  0
# [Lithuanian litas ]         2376
# [Latvian lats ]             2631
# [Maltese lira ]             4189
# [Mexican peso ]                0
# [Malaysian ringgit ]           0
# [Norwegian krone ]             0
# ...

# %%
# Detailed code for missing values 

missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Period\Unit:                   0
# [Australian dollar ]           0
# [Bulgarian lev ]             402
# [Brazilian real ]            268
# [Canadian dollar ]             0
# [Swiss franc ]                 0
# [Chinese yuan renminbi ]     268
# [Cypriot pound ]            4189
# [Czech koruna ]                0
# [Danish krone ]                0
# [Estonian kroon ]           3405
# [UK pound sterling ]           0
# [Greek drachma ]            6015
# [Hong Kong dollar ]            0
# [Croatian kuna ]             594
# [Hungarian forint ]            0
# [Indonesian rupiah ]           0
# [Israeli shekel ]            268
# [Indian rupee ]              268
# [Iceland krona ]            2407
# [Japanese yen ]                0
# [Korean won ]                  0
# [Lithuanian litas ]         2376
# [Latvian lats ]             2631
# [Maltese lira ]             4189
# [Mexican peso ]                0
# [Malaysian ringgit ]           0
# [Norwegian krone ]             0
# ...

# %%
# Imputing missing values with mean 

df_filled_mean =df.fillna(df.mean())

# %%
# Checking for missing values after imputation 

missing_values_after = df_filled_mean.isnull().sum()
print(missing_values_after)
# Out:
# Period\Unit:                   0
# [Australian dollar ]           0
# [Bulgarian lev ]             402
# [Brazilian real ]            268
# [Canadian dollar ]             0
# [Swiss franc ]                 0
# [Chinese yuan renminbi ]     268
# [Cypriot pound ]            4189
# [Czech koruna ]                0
# [Danish krone ]                0
# [Estonian kroon ]           3405
# [UK pound sterling ]           0
# [Greek drachma ]            6015
# [Hong Kong dollar ]            0
# [Croatian kuna ]             594
# [Hungarian forint ]            0
# [Indonesian rupiah ]           0
# [Israeli shekel ]            268
# [Indian rupee ]              268
# [Iceland krona ]               0
# [Japanese yen ]                0
# [Korean won ]                  0
# [Lithuanian litas ]         2376
# [Latvian lats ]             2631
# [Maltese lira ]             4189
# [Mexican peso ]                0
# [Malaysian ringgit ]           0
# [Norwegian krone ]             0
# ...

# %%
# Droping Rows with missing values 

df_dropped = df.dropna()

# %%
# Checkign before and after shape of the data 
print("Shape before dropping:", df.shape)
print("Shape after dropping:", df_dropped.shape)
# Out:
# Shape before dropping: (6535, 41)
# Shape after dropping: (116, 41)

# %%
# Checking Unique Values 


unique_values = df.nunique()
unique_values
# Out:
# Period\Unit:                6535
# [Australian dollar ]        3682
# [Bulgarian lev ]             106
# [Brazilian real ]           5656
# [Canadian dollar ]          3099
# [Swiss franc ]              3388
# [Chinese yuan renminbi ]    5456
# [Cypriot pound ]             498
# [Czech koruna ]             4109
# [Danish krone ]              496
# [Estonian kroon ]              2
# [UK pound sterling ]        3926
# [Greek drachma ]             323
# [Hong Kong dollar ]         5950
# [Croatian kuna ]            2305
# [Hungarian forint ]         4656
# [Indonesian rupiah ]        6437
# [Israeli shekel ]           5280
# [Indian rupee ]             5939
# [Iceland krona ]            1951
# [Japanese yen ]             3842
# [Korean won ]               6073
# [Lithuanian litas ]          771
# [Latvian lats ]             1078
# [Maltese lira ]              426
# [Mexican peso ]             6311
# [Malaysian ringgit ]        5198
# [Norwegian krone ]          4141
# ...

# %%
# Plotting for Quantitative Features

df.hist(figsize=(10,10))
plt.show()

# %%
# Plotting for Object Featurs 

object_columns = df.select_dtypes(include=['object']).columns

# %%
# Plotting bar blots for Object Features 

for column in object_columns:
    
    plt.figure(figsize=(8,6))
    df[column].value_counts().plot(kind='bar')
    plt.title(f'Bar Plot of Currency')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.show()
